# %% [markdown]
# # Python Basics – Part 2
#
# Focus: Writing production-ready Python code
# Purpose: Interview prep + real-world usage

# %%
# ======================================
# pathlib basics
# - Path represents file or directory paths
# - OS independent (Windows/Linux/Mac)
# ======================================

from pathlib import Path

# Get current working directory
base_path = Path.cwd()
print("Base path:", base_path)

# Create a path object (no file created yet)
file_path = base_path / "data" / "sample.txt"
print("File path:", file_path)
# Out:
# Base path: d:\Sourav\Projects\Data Engineering\data-engineering\python\basics
# File path: d:\Sourav\Projects\Data Engineering\data-engineering\python\basics\data\sample.txt

# %%
# ======================================
# Directory creation
# ======================================

data_dir = base_path / "data"
data_dir.mkdir(exist_ok=True)

print("Directory exists:", data_dir.exists())
print("Is directory:", data_dir.is_dir())
# Out:
# Directory exists: True
# Is directory: True

# %%
# ======================================
# Writing text to file
# ======================================

file_path = data_dir / "sample.txt"

file_path.write_text("Hello from pathlib\nThis is line 2")

print("File created:", file_path.exists())
# Out:
# File created: True

# %%
# ======================================
# Reading text from file
# ======================================

content = file_path.read_text()
print(content)
# Out:
# Hello from pathlib
# This is line 2

# %%
# ======================================
# File checks
# ======================================

print("Exists:", file_path.exists())
print("Is file:", file_path.is_file())
print("File name:", file_path.name)
print("File extension:", file_path.suffix)
print(file_path.parent)
# Out:
# Exists: True
# Is file: True
# File name: sample.txt
# File extension: .txt
# d:\Sourav\Projects\Data Engineering\data-engineering\python\basics\data

# %% [markdown]
# ## Exception Handling – Basics

# %%
# ======================================
# Basic exception handling
# ======================================

try:
    x = int("10")
    print("Value:", x)
except ValueError:
    print("Conversion failed")
# Out:
# Value: 10

# %%
# ======================================
# Handling conversion error
# ======================================

try:
    x = int("abc")
    print(x)
except ValueError:
    print("Cannot convert string to int")
# Out:
# Cannot convert string to int

# %%
# ======================================
# Multiple exception handling
# ======================================

try:
    a = 10 / 0
except ZeroDivisionError:
    print("Division by zero")
except ValueError:
    print("Invalid value")
# Out:
# Division by zero

# %%
# ======================================
# finally block
# ======================================

try:
    file = open("test.txt", "r")
except FileNotFoundError:
    print("File not found")
finally:
    print("Execution completed")
# Out:
# File not found
# Execution completed

# %%
# ======================================
# else with try/except
# ======================================

try:
    num = int("5")
except ValueError:
    print("Error occurred")
else:
    print("Conversion successful:", num)
# Out:
# Conversion successful: 5

# %% [markdown]
# ## Custom Exceptions

# %%
# ======================================
# Defining a custom exception
# ======================================

class InvalidAgeError(Exception):
    pass

# %%
# ======================================
# Raising custom exception
# ======================================

def register_user(age):
    if age < 18:
        raise InvalidAgeError("User must be at least 18 years old")
    print("User registered successfully")

register_user(20)
# Out:
# User registered successfully

# %%
register_user(15)
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 register_user(15)
#
# Cell In[3], line 7, in register_user(age)
#       5 def register_user(age):
#       6     if age < 18:
# ----> 7         raise InvalidAgeError("User must be at least 18 years old")
#       8     print("User registered successfully")
#
# InvalidAgeError: User must be at least 18 years old

# %%
# ======================================
# Catching custom exception
# ======================================

try:
    register_user(15)
except InvalidAgeError as e:
    print("Registration failed:", e)
# Out:
# Registration failed: User must be at least 18 years old

# %%
# ======================================
# Custom exception with attributes
# ======================================

class DataQualityError(Exception):
    def __init__(self, message, record_count):
        super().__init__(message)
        self.record_count = record_count

def validate_data(count):
    if count == 0:
        raise DataQualityError("No records found", count)

try:
    validate_data(0)
except DataQualityError as e:
    print(e)
    print("Record count:", e.record_count)
# Out:
# No records found
# Record count: 0

# %% [markdown]
# ## Logging

# %%
# ======================================
# Basic logging setup
# ======================================

import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s"
)

logging.info("Application started")
logging.warning("This is a warning")
logging.error("This is an error")
# Out:
# 2026-01-10 18:39:40,828 | INFO | Application started
# 2026-01-10 18:39:40,829 | WARNING | This is a warning
# 2026-01-10 18:39:40,830 | ERROR | This is an error

# %%
# ======================================
# Logging with dynamic values
# ======================================

user = "Alice"
records = 120

logging.info("User %s processed %d records", user, records)
# Out:
# 2026-01-10 18:41:42,758 | INFO | User Alice processed 120 records

# %%
# ======================================
# Logging exceptions
# ======================================

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.exception("Division by zero occurred")
# Out:
# 2026-01-10 18:43:10,639 | ERROR | Division by zero occurred
# Traceback (most recent call last):
#   File "C:\Users\soura\AppData\Local\Temp\ipykernel_8340\416698102.py", line 6, in <module>
#     x = 10 / 0
# ZeroDivisionError: division by zero

# %%
# ======================================
# Using logger object
# ======================================

logger = logging.getLogger(__name__)

logger.info("Logger initialized")
# Out:
# 2026-01-10 18:45:57,332 | INFO | Logger initialized

# %%
# ======================================
# Logging to a file
# ======================================

import logging
from pathlib import Path

log_dir = Path("logs")
log_dir.mkdir(exist_ok=True)

log_file = log_dir / "app.log"

logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(name)s | %(message)s"
)

logger = logging.getLogger(__name__)

logger.info("Application started")
logger.warning("This is a warning")
logger.error("This is an error")
# Out:
# 2026-01-10 18:53:39,339 | INFO | Application started
# 2026-01-10 18:53:39,341 | WARNING | This is a warning
# 2026-01-10 18:53:39,341 | ERROR | This is an error

# %%
# ======================================
# Config-driven logging using YAML
# ======================================

import logging
import logging.config
import yaml
from pathlib import Path

config_path = Path("config/logging.yaml")

with open(config_path) as f:
    config = yaml.safe_load(f)

logging.config.dictConfig(config)

logger = logging.getLogger("app")

logger.info("Logging configured from YAML")
logger.error("This error is logged via YAML config")
